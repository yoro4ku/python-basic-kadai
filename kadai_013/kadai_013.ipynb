# %%
def calculate_tax(amount, tax):
    amount_tax = amount * tax
    return amount + amount_tax


print(calculate_tax(110, 0.1))
# Out:
# 121.0
